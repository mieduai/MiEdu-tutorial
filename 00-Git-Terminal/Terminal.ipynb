# %% [markdown]
# # 1. Terminal

# %% [markdown]
# Terminal (còn được gọi là *Command line* hay *Console*) dùng để tương tác với máy tính của bạn, hay nói cách khác thay vì dùng chuột để điều khiển máy tính, bạn dùng Terminal và lệnh *Command*. 😎😎😎

# %% [markdown]
# ### Open Terminal on Window

# %% [markdown]
# <video controls width="720" height="480" src="videos/launch_terminal">animation</video>

# %% [markdown]
# ### Làm thế nào để mở Terminal

# %% [markdown]
# 1. On MacOS, open your terminal by searching it in the spotlight search (**⌘ + Space** and **type in "terminal"**)
# 2. On Linux, the keyboard shortcut is **Ctrl + Alt + T**
# 3. On Windows, just open **Git Bash**

# %% [markdown]
# ### Làm thế nào để chạy câu lệnh trong Terminal?

# %% [markdown]
# Chỉ cần đánh lệnh vào Terminal và nhấn **Enter** thôi các bạn 💪

# %% [markdown]
# ### Một số lệnh thông dụng trong Unix

# %% [markdown]
# ![general-command.PNG](./images/general-command.png)

# %% [markdown]
# ### Các lệnh thông đụng để Quản lý thư mục

# %% [markdown]
# Các lệnh này dùng để quản lý thư mục 📂, dĩ nhiên 😄. Bạn sẽ dùng nó di chuyển qua lại , tạo, xóa thư mục, vv.

# %% [markdown]
# #### Quản lý thư mục

# %% [markdown]
# ![directory-command.PNG](./images/directory-command.png)

# %% [markdown]
# 🏆 Nhớ nha các bạn
# 1. Khi các bạn ko biết mình đang ở thư mục nào, gỏ **pwd** nha. Terminal sẽ cho bạn biết bạn đang ở đâu 💪 💪 💪
# 2. ⚠️ Chà, cực kì chú ý với lệnh **rm -rf /** nhé. Có chết củng ko dùng nhé bạn ⚠️

# %% [markdown]
# #### Kiểm tra thư mục

# %% [markdown]
# ![inspecting-command.PNG](./images/inspecting-command.png)

# %% [markdown]
# 🏆 Nhớ kỉ nha các bạn
# 1. Tạo thư mục ẩn bằng lệnh như sau **mkdir .hiddenFolder**
# 2. Dùng lệnh **ls -a** để liệt kê tất cả các thư mục, kể cả *thư mục ẩn*
# 3. Dùng **man <lệnh>** để xem giúp đỡ của lệnh. Ví dụ *man ls*

# %% [markdown]
# # Files

# %% [markdown]
# Với các câu lệnh quản lý tệp (file), bạn có thể tạo, xóa, di chuyển, sao chép, vv files.
# Bạn cần chú ý là:
# - File không cần phải có đuôi file (ví dụ như .txt hoặc .jpg) để có thể sử dụng

# %% [markdown]
# #### Quản lý Files

# %% [markdown]
# ![file-manipulating-command.PNG](./images/file-manipulating-command.PNG)

# %% [markdown]
# #### Kiểm tra file

# %% [markdown]
# ![file-inspecting-command.PNG](./images/file-inspecting-command.PNG)

# %% [markdown]
# 🏆 Nhớ kỉ nha các bạn
# - Trong Terminal, khi các bạn gõ **phím 'tab'** thì Terminal sẽ thực hiện **auto completion** cho bạn
# - Sử dụng ⬆️/⬇️ để xem các lệnh đã thực hiện trước đó nhé 💪
# - Sử dụng **CTRL + R** để hiển thị lịch sử các câu lệnh nha các bạn
# - Đôi lúc màn hình Terminal của bạn đã đầy các câu lệnh, bạn dùng **CRTL + L** để xóa màn hình hen

# %% [markdown]
# # Lý thuyết đủ rồi, mình thực hành tí nha bạn ❤️❤️❤️

# %% [markdown]
# Giả sử bây giờ bạn có một tá các hình ảnh được lưu dưới dạng .png như trong hình 😅 😅 😅

# %% [markdown]
# ![messy-folder.png](images/messy-folder.PNG)

# %% [markdown]
# Chà! mình muốn sắp xếp chúng lại trong thư mục pictures thì làm sao ta? 🤨

# %% [markdown]
# Okie! mình phải tạo thư mục **pictures** trước tiên để lưu lại hình ảnh đã

# %% [markdown]
# Gõ **mkdir pictures** rồi **Enter**

# %% [markdown]
# Sau đó di chuyển chúng vào thư mục pictures thôi

# %% [markdown]
# Gõ **mv \*.png pictures** rồi **Enter**

# %% [markdown]
# Xem lại thành quả nào 😆

# %% [markdown]
# Gõ **ls** rồi **Enter**

# %% [markdown]
# ![cleaner-folder.png](./images/cleaner-folder.png)

# %% [markdown]
# Tuyệt vời, easy job 😁 phải không bạn!!!

# %% [markdown]
# # Sử dụng dấu Pipe **|**

# %% [markdown]
# Đôi khi bạn muốn sử dụng cùng lúc nhiều lệnh với nhau, bạn có thể dùng dấu **|** nha

# %% [markdown]
# Ví dụ, giả sử bây giờ bạn muốn tìm tất cả các Notebook trong folder *vivadata-student* và lọc kết quả với *Challenges*, mình có thể làm như sau:

# %% [markdown]
# **find ./vivadata-student -name "*.ipynb" | grep "Challenges"**

# %% [markdown]
# 📚 Bạn có thể tìm hiểu thêm tại đây nha => [Learn Enough Command Line to Be Dangerous](https://www.learnenough.com/command-line-tutorial/frontmatter)

# %% [markdown]
# # 2. Người dùng và phân quyền trong Unix

# %% [markdown]
# #### Chúng ta sẽ tìm hiểu về:
# - Hệ thống files trong Unix
# - Người sử dụng và phân quyền trong Unix

# %% [markdown]
# ### Cấu trúc hệ thống Unix

# %% [markdown]
# Trong Unix, mọi thứ đều là files. Có nghĩa là tệp, thư mục, socket, ... đều được thể hiện bằng một [Đặc tả tập tin](https://vi.wikipedia.org/wiki/%C4%90%E1%BA%B7c_t%E1%BA%A3_t%E1%BA%ADp_tin)

# %% [markdown]
# Trong Unix bạn sẽ có một **thư mục Root** là cha của tất cả các thư mục con. Chúng ta có thể đi đến thư mục root bằng cách gõ câu lệnh **cd /**. Khi ở thư mục root, bạn thông thường sẽ thấy các thư mục con sau:

# %% [markdown]
# - **bin**: chứa các tệp binary hay nói cách khác là chứa các Commands bạn có thể gọi.
# - **boot**: chứa các tệp hệ thống Unix dùng để chạy hệ thống.
# - **dev**: chứa tất cả các tệp liên quan đến thiết bị như USB, ổ đĩa CD, ...
# - **etc**: chứa các tệp cấu hình của Unix
# - **home**: chứa các tệp của người dùng

# %% [markdown]
# ![root-folder.png](./images/root-folder.png)

# %% [markdown]
# ### Người dùng, nhóm và Super-user

# %% [markdown]
# Bạn đã biết mọi thứ trong Unix đều được thể hiện bằng file, bây giờ bạn sẽ thấy mọi file đều được quản lý bỡi quyền truy cập, cụ thể là:
# - Quyền truy cập được áp dụng trên nhiều đối tượng người dùng khác nhau
# - Mỗi người dùng thuộc vào một nhóm
# - Root là super-user

# %% [markdown]
# 🏆 Nhớ kỉ nha các bạn
# - Với câu lệnh **ls -l \<file>**, bạn có thể thấy phân quyền của tệp đó
# - Sử dụng câu lệnh **chmod** và **chown** để thay đổi quyền của tệp

# %% [markdown]
# ![files-permissions-and-ownership-basics-in-Linux.png](./images/files-permissions-and-ownership-basics-in-Linux.png)

# %% [markdown]
# ➡️ Cách sử dụng super-user

# %% [markdown]
# ```
# # Switch to super user (use exit to go back)\n
# sudo su
# # Execute one command with super user privileges
# sudo apt-get install ...
# ```
